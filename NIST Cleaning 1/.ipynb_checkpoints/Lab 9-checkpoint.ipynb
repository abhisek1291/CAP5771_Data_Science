# %%
import pylab
import pandas as pd
import numpy as np
folder = '1160'
flow = pd.read_csv(folder + "/flow.tsv", na_values=['-'], delimiter="\t", error_bad_lines=False)
occupancy = pd.read_csv(folder + "/occupancy.tsv", na_values=['-'], delimiter="\t", error_bad_lines=False)
speed = pd.read_csv(folder + "/speed.tsv", na_values=['-'], delimiter="\t", error_bad_lines=False)
timestamp = pd.read_csv(folder + "/timestamp.tsv", na_values=['-'], delimiter="\t", error_bad_lines=False)

# %%
df = pd.concat([flow,occupancy,speed,timestamp], axis=1)

# %%
df.columns = ['flow1','flow2','flow3','occupancy1','occupancy2','occupancy3','speed1','speed2','speed3','timestamp']
df.head()
# Out:
#    flow1  flow2  flow3  occupancy1  occupancy2  occupancy3  speed1  speed2  \
# 0      9      4    255         4.0         2.0         4.0    67.0    60.0
# 1     11     10    255         4.0         5.0         4.0    66.0    64.0
# 2     -8      3    255         3.0         1.0         4.0    71.0    63.0
# 3      5      9    255         2.0         3.0         4.0    65.0    70.0
# 4      7     10    255         2.0         4.0         4.0    66.0    64.0
#
#    speed3            timestamp
# 0     0.0  2006-09-01T00:01:07
# 1     0.0  2006-09-01T00:02:07
# 2     0.0  2006-09-01T00:03:07
# 3     0.0  2006-09-01T00:04:07
# 4     0.0  2006-09-01T00:05:08

# %%
df1 =  pd.DataFrame({"flow" : df.flow1, "occupancy" : df.occupancy1,"speed" : df.speed1,"timestamp" : df.timestamp,"detector" : "x"})
df2 = pd.DataFrame({"flow" : df.flow2, "occupancy" : df.occupancy2,"speed" : df.speed2,"timestamp" : df.timestamp,"detector" : "y"})
df3 = pd.DataFrame({"flow" : df.flow3, "occupancy" : df.occupancy3,"speed" : df.speed3,"timestamp" : df.timestamp,"detector" : "z"})

# %%
frames = [df1, df2, df3]
result = pd.concat(frames)

# %%
result = result.sort_values("timestamp")

# %%
removeResult1 = result[(result['speed'] < 0) | (result['flow'] < 0)]
removeResult2 = result[(result['flow'] == 0) & (result['speed'] > 0)]
jam_occupancy_threshold = 80
removeResult3 = result[((result['speed'] == 0) & 
                            (result['flow'] == 0) & 
                            (result['occupancy'] != 0) & 
                            (result['occupancy'] < jam_occupancy_threshold))]

# %%
res = result.set_index(["timestamp","detector"]).sort_index()

# %%
result = pd.concat([result,removeResult1,removeResult1]).drop_duplicates(keep=False)
result = pd.concat([result,removeResult2,removeResult2]).drop_duplicates(keep=False)
result = pd.concat([result,removeResult3,removeResult3]).drop_duplicates(keep=False)

# %%
result = result.sort_values(["flow"])

# %%
low = 0;
high1 = int(len(result)/20)
BinNum = 20;
length = high1 - low
flowBins = np.zeros(shape=(20,high1), dtype = object)
for i in range(0, 20, 1):
    high = low + high1
    print(str(low) + '\t' + str(high))
    flowBins[i] = [result[low : high]]
    low = high
# Out:
# 0	535004
# 535004	1070008
# 1070008	1605012
# 1605012	2140016
# 2140016	2675020
# 2675020	3210024
# 3210024	3745028
# 3745028	4280032
# 4280032	4815036
# 4815036	5350040
# 5350040	5885044
# 5885044	6420048
# 6420048	6955052
# 6955052	7490056
# 7490056	8025060
# 8025060	8560064
# 8560064	9095068
# 9095068	9630072
# 9630072	10165076
# 10165076	10700080

# %%
import numpy as np
flow_occupancy_bin = np.ndarray(shape=(20,20), dtype = object)
y = 1;
low = 0;
for i in range(0,20,1):
    data = pd.DataFrame(flowBins[i].reshape((-1,length))[0][0]);
    data = data.sort_values(["occupancy"])
    high1 = int(len(flowBins[1])/20)
    low = 0
    for j in range(0, 20, 1):
        high = low + high1
        flow_occupancy_bin[i][j] = [data[low : high]]
        low = high

# %%
flowBins[2].reshape((-1,length))[0][0]
# Out:
#         detector  flow  occupancy  speed            timestamp
# 2738138        x     0        0.0    0.0  2012-08-21T09:55:08
# 2738139        x     0        0.0    0.0  2012-08-21T09:56:08
# 2738139        y     0        0.0    0.0  2012-08-21T09:56:08
# 2738140        y     0        0.0    0.0  2012-08-21T09:57:08
# 2738140        x     0        0.0    0.0  2012-08-21T09:57:08
# 2738141        y     0        0.0    0.0  2012-08-21T09:58:08
# 2738141        x     0        0.0    0.0  2012-08-21T09:58:08
# 2738138        y     0        0.0    0.0  2012-08-21T09:55:08
# 2738101        y     0        0.0    0.0  2012-08-21T09:18:08
# 2738132        y     0        0.0    0.0  2012-08-21T09:49:08
# 2738131        y     0        0.0    0.0  2012-08-21T09:48:08
# 2738123        x     0        0.0    0.0  2012-08-21T09:40:08
# 2738123        y     0        0.0    0.0  2012-08-21T09:40:08
# 2738124        y     0        0.0    0.0  2012-08-21T09:41:08
# 2738124        x     0        0.0    0.0  2012-08-21T09:41:08
# 2738125        y     0        0.0    0.0  2012-08-21T09:42:08
# 2738125        x     0        0.0    0.0  2012-08-21T09:42:08
# 2738126        x     0        0.0    0.0  2012-08-21T09:43:08
# 2738131        x     0        0.0    0.0  2012-08-21T09:48:08
# 2738126        y     0        0.0    0.0  2012-08-21T09:43:08
# 2738127        y     0        0.0    0.0  2012-08-21T09:44:08
# 2738128        x     0        0.0    0.0  2012-08-21T09:45:08
# 2738128        y     0        0.0    0.0  2012-08-21T09:45:08
# 2738129        x     0        0.0    0.0  2012-08-21T09:46:08
# 2738129        y     0        0.0    0.0  2012-08-21T09:46:08
# 2738130        y     0        0.0    0.0  2012-08-21T09:47:08
# 2738130        x     0        0.0    0.0  2012-08-21T09:47:08
# 2738127        x     0        0.0    0.0  2012-08-21T09:44:08
# 2738060        x     0        0.0    0.0  2012-08-21T08:37:08
# 2738100        y     0        0.0    0.0  2012-08-21T09:17:08
# ...          ...   ...        ...    ...                  ...
# 1944943        y     0        0.0    0.0  2011-01-21T01:03:13
# 1944942        y     0        0.0    0.0  2011-01-21T01:02:13
# 1944942        x     0        0.0    0.0  2011-01-21T01:02:13
# 1944945        y     0        0.0    0.0  2011-01-21T01:05:13
# 1944941        y     0        0.0    0.0  2011-01-21T01:01:13
# 1944940        x     0        0.0    0.0  2011-01-21T01:00:13
# 1944940        y     0        0.0    0.0  2011-01-21T01:00:13
# 1944939        x     0        0.0    0.0  2011-01-21T00:59:13
# 1944939        y     0        0.0    0.0  2011-01-21T00:59:13
# 1944938        y     0        0.0    0.0  2011-01-21T00:58:13
# 2217987        x     0        0.0    0.0  2011-08-08T03:48:22
# 1944938        x     0        0.0    0.0  2011-01-21T00:58:13
# 1944941        x     0        0.0    0.0  2011-01-21T01:01:13
# 1944937        x     0        0.0    0.0  2011-01-21T00:57:13
# 1944945        z     0        0.0    0.0  2011-01-21T01:05:13
# 1944947        y     0        0.0    0.0  2011-01-21T01:07:13
# 1944953        x     0        0.0    0.0  2011-01-21T01:13:13
# 1944953        y     0        0.0    0.0  2011-01-21T01:13:13
# 1944953        z     0        0.0    0.0  2011-01-21T01:13:13
# 1944952        y     0        0.0    0.0  2011-01-21T01:12:13
# 1944952        x     0        0.0    0.0  2011-01-21T01:12:13
# 1944951        x     0        0.0    0.0  2011-01-21T01:11:13
# 1944951        y     0        0.0    0.0  2011-01-21T01:11:13
# 1944946        y     0        0.0    0.0  2011-01-21T01:06:13
# 1944950        y     0        0.0    0.0  2011-01-21T01:10:13
# 1944949        z     0        0.0    0.0  2011-01-21T01:09:13
# 1944949        y     0        0.0    0.0  2011-01-21T01:09:13
# 1944949        x     0        0.0    0.0  2011-01-21T01:09:13
# 1944948        z     0        0.0    0.0  2011-01-21T01:08:13
# 1944948        x     0        0.0    0.0  2011-01-21T01:08:13
#
# [535004 rows x 5 columns]

# %%
flow_occupancy_bin.shape
# Out:
# (20, 20)

# %%
int(len(flow_occupancy_bin[0][0][0])/20)
# Out:
# 1337

# %%
import numpy as np
flow_occupancy_speed_bin = np.ndarray(shape=(20,20,20), dtype = object)
y = 1;

for i in range(0,20,1):
    for k in range(0,20,1):
        data = flow_occupancy_bin[i][k][0];
        data = data.sort_values(["speed"])
        low = 0;
        high1 = int(len(flow_occupancy_bin[0][0][0])/20)
        for j in range(0, 20, 1):
            high = low + high1
            print('data, low, high' + str(data.shape) + '\t' + str(low) + '\t' + str(high))
            flow_occupancy_speed_bin[i][k][j] = [data[low : high]]
            low = high
# Out:
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# ...
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
# data, low, high(26750, 5)	21392	22729
# data, low, high(26750, 5)	22729	24066
# data, low, high(26750, 5)	24066	25403
# data, low, high(26750, 5)	25403	26740
# data, low, high(26750, 5)	0	1337
# data, low, high(26750, 5)	1337	2674
# data, low, high(26750, 5)	2674	4011
# data, low, high(26750, 5)	4011	5348
# data, low, high(26750, 5)	5348	6685
# data, low, high(26750, 5)	6685	8022
# data, low, high(26750, 5)	8022	9359
# data, low, high(26750, 5)	9359	10696
# data, low, high(26750, 5)	10696	12033
# data, low, high(26750, 5)	12033	13370
# data, low, high(26750, 5)	13370	14707
# data, low, high(26750, 5)	14707	16044
# data, low, high(26750, 5)	16044	17381
# data, low, high(26750, 5)	17381	18718
# data, low, high(26750, 5)	18718	20055
# data, low, high(26750, 5)	20055	21392
#  144026         z     4        1.0   62.0  2007-02-05T21:32:31
#  404230         y     4        1.0   58.0  2007-09-13T23:40:47
#  ...          ...   ...        ...    ...                  ...
#  1649838        y     4        1.0   65.0  2010-05-15T02:59:49
#  787574         z     4        1.0   43.0  2008-07-17T07:09:11
#  1649836        x     4        1.0   63.0  2010-05-15T02:57:49
#  668322         x     4        1.0   59.0  2008-04-20T23:11:13
#  1649908        x     4        1.0   68.0  2010-05-15T04:09:49
#  1385706        z     4        1.0   81.0  2009-10-10T23:32:37
#  1385712        x     4        1.0   61.0  2009-10-10T23:38:37
#  1166386        z     4        1.0   81.0  2009-05-08T22:49:55
#  161211         z     4        1.0   59.0  2007-02-23T07:33:58
#  1543064        z     4        1.0   70.0  2010-01-31T02:45:00
#  1385713        z     4        1.0   70.0  2009-10-10T23:39:37
#  863573         x     4        1.0   63.0  2008-09-09T22:52:14
#  1385714        z     4        1.0   81.0  2009-10-10T23:40:37
#  1327734        z     4        1.0   81.0  2009-08-30T23:28:28
#  863574         z     4        1.0   62.0  2008-09-09T22:53:14
#  1166422        z     4        1.0   70.0  2009-05-08T23:25:55
#  161208         z     4        1.0   79.0  2007-02-23T07:30:57
#  1475791        z     4        1.0   81.0  2009-12-12T20:02:04
#  1385758        z     4        1.0   81.0  2009-10-11T00:24:37
#  1666032        z     4        1.0   98.0  2010-05-26T09:30:21
#  482921         x     4        1.0    0.0  2007-11-23T14:03:07
#  1649905        x     4        1.0   67.0  2010-05-15T04:06:49
#  1166420        z     4        1.0   81.0  2009-05-08T23:23:55
#  1327689        y     4        1.0   62.0  2009-08-30T22:42:28
#  863947         z     4        1.0   50.0  2008-09-10T05:14:24
#  1166415        z     4        1.0   81.0  2009-05-08T23:18:55
#  1514594        z     4        1.0   70.0  2010-01-10T23:21:20
#  1327735        x     4        1.0   68.0  2009-08-30T23:29:28
#  482922         x     4        1.0    0.0  2007-11-23T14:04:07
#  787549         z     4        1.0   41.0  2008-07-17T06:44:10
#
#  [26750 rows x 5 columns]]

# %%
prob_data = flowBins[18][0]

# %%
currVectors = flow_occupancy_speed_bin[18][18][18][0].shape[0]
vectors = len(result)
for j in range(1,20,1):
    for k in range(1,20,1):
        prob_data = flow_occupancy_speed_bin[18][j][k][0]
        f = prob_data.flow.max() - prob_data.flow.min()
        o = prob_data.occupancy.max() - prob_data.occupancy.min()
        s = prob_data.speed.max() - prob_data.speed.min()
        volume = f*o*s
        if(volume == 0): volume =1
        probability = currVectors/float(vectors * volume)
        print(probability)
# Out:
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 1.1018714288188346e-07
# 4.338618750974161e-07
# 1.4875264289054267e-06
# 1.7354475003896645e-06
# 0.00012495222002805584
# 6.941790001558658e-06
# 3.470895000779329e-06
# 0.00012495222002805584
# 2.9750528578108533e-06
# 0.00012495222002805584
# 3.470895000779329e-06
# 0.00012495222002805584
# 0.00012495222002805584
# 4.1650740009351945e-06
# 0.00012495222002805584
# 2.9750528578108533e-06
# 3.470895000779329e-06
# 3.470895000779329e-06
# 7.437632144527133e-08
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
# 0.00012495222002805584
#